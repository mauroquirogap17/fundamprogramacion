# %% [markdown]
# **Es integrar Ciclos y Funciones en el código del Taller 1 y Taller 2.**

# %%
#Funciones para mostrar los datos del empleado
def mostrar_nombre(nomb):
    print("\nNombre: ",nomb)

def mostrar_apellido(ape):
    print("\nApellido: ",ape)

def mostrar_identi(numid):
    print("\nNumero de Identificacion: ",numid)

def mostrar_dir(dire):
    print("\nDireccion: ",dire)

def mostrar_tel(tel):
    print("\nNumero de Telefono: ",tel)

def mostrar_edad(eda):
    print("\nEdad: ",eda)

def mostrar_est_civil(civil):
    print("\nEstado civil: ",civil)

def mostrar_hijos(hijos):
    print("\nCantidad de hijos: ",hijos)

def mostrar_estatura(est):
    print("\nEstatura: ",est,"cms")

def mostrar_fecha_cont(contrat):
    print("\nFecha de contratacion: ",contrat)

def mostrar_identi(numid):
    print("\nNumero de Identificacion: ",numid)

def mostrar_sueldo(sueld):
    print("\nSueldo: $",sueld)

def mostrar_dias_lab(laborados):
    print("\nDias laborados: ",laborados)

def validacion_bono(sueld):
    if edad > 55:
      bono = sueld * 0.05
      print(f"\n*-*-**-*-**-*-**-*-**-*-**-*-*\nPor edad aplica para bono prepension de= ${bono:,.0f}")
    else:
     print("\n*-*-**-*-**-*-**-*-**-*-**-*-*\n\nNo aplica para bono prepension")

def validacion_paseo (hijos,civil):
  if civil == "casado" or civil == "Casado" and hijos > 0:
   print("\nAplica para paseo en diciembre")
  else:
   print("\nNo Aplica para paseo en diciembre")

def validacion_comision (sueld):
  if sueldo >= 1000000 and sueldo <= 1500000:
   com_dos =sueld * 0.02
   print(f"\nPor sueldo aplica para comision de 2%= ${com_dos:,.0f}")
  elif sueld >= 1500001 and sueld <= 2000000:
   com_cinco =sueld * 0.05
   print(f"\nPor sueldo aplica para comision de 5%= ${com_cinco:,.0f}")
  else:
   print("\nNo aplica para comision por sueldo")

def valida_alimentacion(dias_lab,sueld):
  if dias_lab > 20 and sueld < 1000000:
   print(f"\nTiene derecho a bono de alimentacion")
  else:
   print("\nNo aplica para bono de alimentacion")

resp = "si"
while resp == "si" or resp == "s":

  #Variables para capturar los datos del empleado
  nombre = input("Digite su nombre: ")
  apellido = input("Digite su apellido ")
  num_identi = input("Digite su numero de identificacion ")
  dir = input("Digite su direccion ")
  telefono = input("Digite su numero de telefono ")
  edad = int(input("Digite su edad "))
  est_civil = input("Digite su estado civil ")
  num_hijos = int(input("Digite cuantos hijos tiene "))
  estatura = input("Digite su estatura en centimetros ")
  fecha_cont = input("Digite la fecha de contratacion (Dia/Mes/Año) ")
  sueldo = float(input("Digite su sueldo basico "))
  dias_labo = int(input("Digite la cantidad de dias laborados "))

  # Invocacion de funciones 
  mostrar_nombre(nombre)
  mostrar_apellido(apellido)
  mostrar_identi(num_identi)
  mostrar_dir(dir)
  mostrar_tel (telefono)
  mostrar_edad(edad)
  mostrar_est_civil(est_civil)
  mostrar_hijos(num_hijos)
  mostrar_estatura(estatura)
  mostrar_fecha_cont(fecha_cont)
  mostrar_sueldo(sueldo)
  mostrar_dias_lab(dias_labo)
  validacion_bono(sueldo)
  validacion_paseo(num_hijos,est_civil)
  validacion_comision(sueldo)
  valida_alimentacion(dias_labo,sueldo)
  resp = input("¿Desea validar otro empleado? ")
